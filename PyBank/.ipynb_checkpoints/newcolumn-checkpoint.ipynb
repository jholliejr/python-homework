# %%
# testing how to add new column to dataset
import pandas as pd
from pathlib import Path
test_column = Path("budget_data.csv")


new_columndf = pd.read_csv(test_column)

nt_total_months = new_columndf['Date'].count()
# print(nt_total_months)

# check on data
# print(new_columndf.head())

# create data for new column
daily_change = new_columndf['Profit/Losses'] - new_columndf['Profit/Losses'].shift(1)
new_columndf['D-Diff'] = daily_change
# print(new_columndf)
#
# print max differnce
yuting_sugg = new_columndf['D-Diff'].max()
print(yuting_sugg)
# print min difference
ys2 = new_columndf['D-Diff'].min()
print('min amount is ', ys2)

# colunm_list = {new_columndf}
# print(new_columndf)


"""for i in range(len(column_list)):
    column_dict[column_list[i]] = column_list.count(column_list[i])
print(column_dict)
"""
# check on data from daily change
"""test_list = ["money", "power", "fame",
         "4/20/20", "3500", "250",
         "3/15/70", "4300", "175"]

test_dict = {}

for i in range(len(test_list)):
    test_dict[test_list[i]] = test_list.count(test_list[i])

print(test_dict)
"""

# dictionary
"""dict_att = {}

for i in range(len(new_columndf)):
    dict_att[new_columndf[i]] = new_columndf.count([i])
print(dict_att)
"""

# find largest one day change
# greatest_change_finder = [daily_change.nlargest(nt_total_months)]
# greatest_change = greatest_change_finder
# print('greatest_change is ', greatest_change)

# yuting_sugg = new_columndf["daily_change"].max()
# print(yuting_sugg)

# trying to find second largest change
# x = 1
# greatest_change_finder2 = [daily_change.nlargest(nt_total_months) - x]

# greatest_change2 = greatest_change_finder2
# print('second greatest date ', greatest_change2)


# greatest_change_date = greatest_change
# print('date was', daily_change[0:2])

# greatest_change_pl = greatest_change[]
# print("the greatest one-day change was" greatest_change[1])

# how to print row of greatest change
# print(new_columndf[0,1])

# for gc in greatest_change
# print(gc[0])

         
# print(df.loc[greatest_change, 1:1])

# add a new column
# get the average of the differences
# change_total = daily_change.sum()

# check change sum
# print(round(change_total), 2)

# calculate average change total
# total_avg_change = change_total / nt_total_months
# print(round(total_avg_change), 2)

# new_columndf = pd.dataframe({'Daily Change': daily_change})

# check for new column and data
# new_columnf.head()

# daily_change = pd.array(new_columndf({'daily change'}, ])
# print(daily_change)
# Out:
# 1926159.0
# min amount is  -2196167.0
# 'dict_att = {}\n\nfor i in range(len(new_columndf)):\n    dict_att[new_columndf[i]] = new_columndf.count([i])\nprint(dict_att)\n'
